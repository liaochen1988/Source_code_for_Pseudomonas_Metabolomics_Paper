# %%
import string
from copy import deepcopy
import pandas as pd
import numpy as np
from sklearn.decomposition import NMF
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Read normalized mean growth curve

# %%
df_mean_gc = pd.read_csv('../data/growth_curve_normalized/normalized_mean_growth_curve_PA_glycerol.csv', index_col=0)
df_mean_gc.index.name = 'Time'
df_mean_gc.head()
# Out:
#         F20590    F22031    F23197    F30658    F34365     F5677    F63912  \
# Time
# 0.0   0.003337  0.006417  0.003265  0.005668  0.005560  0.003057  0.006183
# 0.1   0.003364  0.005618  0.003375  0.005207  0.007122  0.003108  0.005308
# 0.2   0.003365  0.005404  0.003413  0.005176  0.007383  0.003115  0.005267
# 0.3   0.003333  0.005443  0.003417  0.005634  0.006474  0.003074  0.006321
# 0.4   0.003418  0.005420  0.003484  0.005554  0.006201  0.003155  0.006495
#
#          F9670    H27930    H47921  ...    T63266    W16407    W25637  \
# Time                                ...
# 0.0   0.004500  0.004367  0.005983  ...  0.001366  0.000287  0.001771
# 0.1   0.003876  0.003965  0.004442  ...  0.001366  0.000287  0.001771
# 0.2   0.003800  0.003876  0.003810  ...  0.001418  0.000392  0.001918
# 0.3   0.004326  0.003998  0.003619  ...  0.001893  0.001340  0.003336
# 0.4   0.004710  0.004263  0.003769  ...  0.001790  0.001355  0.003887
#
#         W36662    W45909    W60856    W70332    W91453    X78812     X9820
# Time
# 0.0   0.003265  0.000017  0.003639  0.000965  0.001764  0.002561  0.000554
# 0.1   0.003373  0.000017  0.003704  0.000965  0.002041  0.003024  0.000554
# 0.2   0.003433  0.000032  0.003795  0.000965  0.002554  0.003628  0.000554
# 0.3   0.003460  0.000247  0.003924  0.000965  0.003489  0.004463  0.000554
# 0.4   0.003503  0.000861  0.004042  0.001252  0.003603  0.004295  0.000931
#
# [5 rows x 34 columns]

# %% [markdown]
# # Read rhamnolipid production category

# %%
df_rhl = pd.read_excel('../data/rhamnolipids/rhamnMat.xlsx')
df_rhl.head()
# Out:
#    strain  rhamn3cats  rhamn2cats
# 0  F22031           2           1
# 1  F23197           2           1
# 2  F30658           1           1
# 3  F34365           2           1
# 4   F5677           0           0

# %% [markdown]
# # Find shared strains between growth curve data and rhamnolipid production data

# %%
shared_strains = list(set(df_mean_gc.columns).intersection(set(df_rhl.strain)))
df_mean_gc = df_mean_gc[shared_strains]
df_rhl = df_rhl[df_rhl.strain.isin(shared_strains)]

# %% [markdown]
# # Plot all growth curves in a single graph

# %% [markdown]
# ## plot individual curves

# %%
fig, ax = plt.subplots(1,1,figsize=(6,6))
for strain in df_mean_gc.columns:
    is_RL_producer = df_rhl.loc[df_rhl.strain==strain,'rhamn2cats'].values
    if is_RL_producer:
        plt.plot(df_mean_gc.index, df_mean_gc[strain], color='darkorange')
    else:
        plt.plot(df_mean_gc.index, df_mean_gc[strain], color='royalblue')
_ = plt.xlabel('Time (hour)',fontsize=20)
_ = plt.ylabel('OD',fontsize=20)
_ = plt.xticks([0,10,20,30,40,50], fontsize=16)
_ = plt.yticks([0,0.3,0.6,0.9,1.2], fontsize=16)
fig.savefig('growth_curves_grouped_by_rhamn2cat.svg', format='svg', dpi=1200)

# %% [markdown]
# ## plot shades only

# %%
df_mean_gc_sns_format = df_mean_gc.stack().to_frame().reset_index()
df_mean_gc_sns_format.columns = ['time','strain','od']
df_mean_gc_sns_format = pd.merge(df_mean_gc_sns_format, df_rhl)
df_mean_gc_sns_format.head()
# Out:
#    time  strain        od  rhamn3cats  rhamn2cats
# 0   0.0  F22031  0.006417           2           1
# 1   0.1  F22031  0.005618           2           1
# 2   0.2  F22031  0.005404           2           1
# 3   0.3  F22031  0.005443           2           1
# 4   0.4  F22031  0.005420           2           1

# %%
fig, ax = plt.subplots(1,1,figsize=(6,6))
sns.lineplot(x='time',y='od',hue='rhamn2cats',data=df_mean_gc_sns_format,ax=ax,palette={0:'royalblue',1:'darkorange'})
_ = plt.xlabel('Time (hour)',fontsize=20)
_ = plt.ylabel('OD',fontsize=20)
_ = plt.xticks([0,10,20,30,40,50], fontsize=16)
_ = plt.yticks([0,0.3,0.6,0.9,1.2], fontsize=16)

# %% [markdown]
# # Non-Negative Matrix Factorization

# %%
# perform non-negative matrix factorization
model = NMF(n_components=3, init='random', random_state=0, tol=1e-8)
W = model.fit_transform(df_mean_gc.values)
H = model.components_
    
# plot
fig, ax = plt.subplots(2,3,figsize=(16,8))
    
# plot basis function
for i in range(0,W.shape[1]):
    ax[0,0].plot(df_mean_gc.index, W[:,i], label='basis'+str(i))
ax[0,0].legend()
_ = ax[0,0].set_xlabel('Time (hour)',fontsize=16)
_ = ax[0,0].set_ylabel('OD',fontsize=16)
        
# plot weights
df_H = pd.DataFrame(H.transpose(), index=df_mean_gc.columns)
df_H = df_H.stack().to_frame().reset_index()
df_H.columns = ['strain','basis','weights']
    
res = []
for strain in df_H.strain:
    res.append(df_rhl.loc[df_rhl.strain==strain,['rhamn2cats','rhamn3cats']].values.tolist()[0])
df_res = pd.DataFrame(res, index=df_H.index)
df_res.columns = ['rhamn2cats','rhamn3cats']
df_H = pd.concat([df_H, df_res], axis=1)
    
sns.boxplot(x="basis", y="weights", hue="rhamn2cats", data=df_H, palette={0:'royalblue',1:'darkorange'}, ax=ax[0,1])
_ = ax[0,1].set_xlabel('Basis',fontsize=16)
_ = ax[0,1].set_ylabel('Weights',fontsize=16)
    
sns.boxplot(x="basis", y="weights", hue="rhamn3cats", data=df_H, palette={0:'royalblue',1:'darkorange',2:'limegreen'}, ax=ax[0,2])
_ = ax[0,2].set_xlabel('Basis',fontsize=16)
_ = ax[0,2].set_ylabel('Weights',fontsize=16)
    
# basis multiplied by weights
for basis in [0,1,2]:
    df_weighted_basis = pd.DataFrame(index=df_mean_gc.index, columns=df_mean_gc.columns)
    for index,strain in enumerate(df_weighted_basis.columns):
        df_weighted_basis[strain] = W[:,basis]*H[basis,index]
    df_weighted_basis_sns_format = df_weighted_basis.stack().to_frame().reset_index()
    df_weighted_basis_sns_format.columns = ['time','strain','od']
    df_weighted_basis_sns_format = pd.merge(df_weighted_basis_sns_format, df_rhl)
    
    sns.lineplot(x='time',y='od',hue='rhamn2cats',data=df_weighted_basis_sns_format,ax=ax[1,basis],palette={0:'royalblue',1:'darkorange'})
    _ = ax[1,basis].set_xlabel('Time (hour)',fontsize=16)
    _ = ax[1,basis].set_ylabel('OD',fontsize=16)
    
plt.tight_layout()
plt.show()

fig.savefig('nnmf.svg', format='svg', dpi=1200)

# %% [markdown]
# # test significance of weights difference between RL producer and non-producers

# %%
for i in [0,1,2]:
    df_H_basis_i = df_H[df_H.basis == i]
    RL_non_producing_group = df_H_basis_i.loc[df_H_basis_i.rhamn2cats==0,'weights']
    RL_producing_group = df_H_basis_i.loc[df_H_basis_i.rhamn2cats==1,'weights']
    _,pval = scipy.stats.ttest_ind(RL_non_producing_group, RL_producing_group, equal_var=False)
    print(pval)
# Out:
# 0.0036231988403189253
# 0.01814393719982201
# 0.939065493869222

# %% [markdown]
# # Using supervised learning to extract features

# %% [markdown]
# ## extract growth curve features

# %%
# %run auxiliary_function.py

df_growth_curve_feature = extract_growth_curve_features(
    file_od='../data/growth_curve_normalized/normalized_mean_growth_curve_PA_glycerol.csv',
    file_phase='../determine_growth_phases/PA_glycerol_growth_phase_start_time.csv',
    plot_dim=[5,7]
)
# Out:
# strain=F22031, phase=1, start_time=3.30, start_od=0.01, area=1.45, best_model=EXP (r2=1.00), growth_rate = [0.09, 0.02], specific_growth_rate = [0.25, 0.25]
# strain=F22031, phase=2, start_time=20.60, start_od=0.35, area=11.99, best_model=EXP (r2=0.95), growth_rate = [0.07, 0.04], specific_growth_rate = [0.06, 0.06]
# strain=F22031, phase=3, start_time=36.70, start_od=1.02, area=11.24, best_model=EXP (r2=0.99), growth_rate = [0.00, -0.00], specific_growth_rate = [0.00, -0.00]
# strain=F23197, phase=1, start_time=12.80, start_od=0.01, area=2.44, best_model=EXP (r2=0.98), growth_rate = [0.09, 0.02], specific_growth_rate = [0.19, 0.19]
# strain=F23197, phase=2, start_time=32.50, start_od=0.42, area=7.57, best_model=EXP (r2=0.98), growth_rate = [0.05, 0.04], specific_growth_rate = [0.06, 0.06]
# strain=F23197, phase=3, start_time=43.60, start_od=0.89, area=3.76, best_model=EXP (r2=0.94), growth_rate = [0.02, -0.02], specific_growth_rate = [0.02, -0.02]
# strain=F30658, phase=1, start_time=4.40, start_od=0.01, area=1.03, best_model=EXP (r2=0.96), growth_rate = [0.19, 0.02], specific_growth_rate = [0.52, 0.16]
# strain=F30658, phase=2, start_time=22.20, start_od=0.39, area=4.15, best_model=GOM (r2=0.99), growth_rate = [0.15, 0.06], specific_growth_rate = [0.39, 0.11]
# strain=F30658, phase=3, start_time=28.40, start_od=0.80, area=12.67, best_model=EXP (r2=0.98), growth_rate = [0.01, -0.02], specific_growth_rate = [0.03, -0.03]
# strain=F34365, phase=1, start_time=4.40, start_od=0.01, area=1.51, best_model=EXP (r2=1.00), growth_rate = [0.10, 0.02], specific_growth_rate = [0.26, 0.23]
# strain=F34365, phase=2, start_time=21.50, start_od=0.38, area=10.57, best_model=EXP (r2=0.97), growth_rate = [0.05, 0.04], specific_growth_rate = [0.05, 0.05]
# strain=F34365, phase=3, start_time=36.30, start_od=0.95, area=10.55, best_model=EXP (r2=0.94), growth_rate = [0.00, -0.01], specific_growth_rate = [0.00, -0.01]
# strain=F5677, phase=1, start_time=15.40, start_od=0.01, area=7.11, best_model=EXP (r2=0.99), growth_rate = [0.06, 0.02], specific_growth_rate = [0.09, 0.09]
# strain=F5677, phase=2, start_time=47.90, start_od=0.65, area=0.07, best_model=EXP (r2=1.00), growth_rate = [0.04, 0.04], specific_growth_rate = [0.06, 0.06]
# strain=F5677, phase=3, start_time=48.00, start_od=0.66, area=0.00, best_model=EXP (r2=0.00), growth_rate = [0.00, 0.00], specific_growth_rate = [0.01, 0.01]
# strain=F63912, phase=1, start_time=4.40, start_od=0.01, area=4.14, best_model=EXP (r2=0.97), growth_rate = [0.13, 0.04], specific_growth_rate = [0.17, 0.17]
# strain=F63912, phase=2, start_time=25.60, start_od=0.70, area=6.07, best_model=EXP (r2=0.98), growth_rate = [0.07, 0.06], specific_growth_rate = [0.06, 0.06]
# strain=F63912, phase=3, start_time=32.30, start_od=1.06, area=14.96, best_model=EXP (r2=1.00), growth_rate = [0.01, -0.02], specific_growth_rate = [0.01, -0.02]
# strain=F9670, phase=1, start_time=5.00, start_od=0.01, area=1.63, best_model=EXP (r2=0.99), growth_rate = [0.22, 0.03], specific_growth_rate = [0.40, 0.19]
# strain=F9670, phase=2, start_time=23.50, start_od=0.63, area=16.67, best_model=GOM (r2=0.92), growth_rate = [0.17, 0.03], specific_growth_rate = [0.23, 0.03]
# strain=F9670, phase=3, start_time=38.60, start_od=1.23, area=10.59, best_model=LGX (r2=0.98), growth_rate = [0.00, -0.02], specific_growth_rate = [0.00, -0.01]
# strain=H27930, phase=1, start_time=4.70, start_od=0.01, area=1.34, best_model=EXP (r2=1.00), growth_rate = [0.11, 0.03], specific_growth_rate = [0.29, 0.28]
# strain=H27930, phase=2, start_time=19.60, start_od=0.39, area=14.05, best_model=EXP (r2=0.97), growth_rate = [0.05, 0.03], specific_growth_rate = [0.04, 0.04]
# strain=H27930, phase=3, start_time=37.50, start_od=1.10, area=10.86, best_model=EXP (r2=1.00), growth_rate = [0.00, -0.01], specific_growth_rate = [0.00, -0.01]
# strain=H47921, phase=1, start_time=9.00, start_od=0.01, area=1.19, best_model=EXP (r2=0.98), growth_rate = [0.28, 0.03], specific_growth_rate = [0.56, 0.20]
# strain=H47921, phase=2, start_time=24.10, start_od=0.56, area=14.49, best_model=LGX (r2=0.88), growth_rate = [0.05, 0.03], specific_growth_rate = [0.07, 0.03]
# strain=H47921, phase=3, start_time=38.00, start_od=1.28, area=10.62, best_model=EXP (r2=0.92), growth_rate = [0.00, -0.04], specific_growth_rate = [0.00, -0.03]
# strain=H5708, phase=1, start_time=4.40, start_od=0.01, area=5.51, best_model=EXP (r2=0.98), growth_rate = [0.16, 0.04], specific_growth_rate = [0.17, 0.17]
# strain=H5708, phase=2, start_time=28.30, start_od=0.90, area=4.94, best_model=LGX (r2=0.92), growth_rate = [0.00, 0.00], specific_growth_rate = [0.00, 0.00]
# strain=H5708, phase=3, start_time=32.80, start_od=1.18, area=14.15, best_model=LGX (r2=0.00), growth_rate = [0.00, 0.00], specific_growth_rate = [0.00, 0.00]
# strain=M1608, phase=1, start_time=3.70, start_od=0.00, area=2.28, best_model=EXP (r2=0.99), growth_rate = [0.06, 0.02], specific_growth_rate = [0.17, 0.17]
# strain=M1608, phase=2, start_time=27.70, start_od=0.36, area=9.28, best_model=EXP (r2=0.99), growth_rate = [0.04, 0.03], specific_growth_rate = [0.05, 0.05]
# strain=M1608, phase=3, start_time=43.50, start_od=0.80, area=3.47, best_model=EXP (r2=0.90), growth_rate = [0.01, -0.02], specific_growth_rate = [0.02, -0.02]
# strain=M37351, phase=1, start_time=8.50, start_od=0.01, area=4.75, best_model=EXP (r2=0.97), growth_rate = [0.06, 0.02], specific_growth_rate = [0.10, 0.10]
# strain=M37351, phase=2, start_time=36.30, start_od=0.53, area=1.72, best_model=GOM (r2=1.00), growth_rate = [0.77, 0.14], specific_growth_rate = [1.44, 0.22]
# strain=M37351, phase=3, start_time=38.50, start_od=0.83, area=7.77, best_model=EXP (r2=0.99), growth_rate = [0.00, -0.00], specific_growth_rate = [0.00, -0.01]
# strain=M55212, phase=1, start_time=13.90, start_od=0.01, area=3.59, best_model=EXP (r2=0.99), growth_rate = [0.07, 0.02], specific_growth_rate = [0.13, 0.13]
# strain=M55212, phase=2, start_time=41.00, start_od=0.57, area=3.50, best_model=GOM (r2=1.00), growth_rate = [0.22, 0.06], specific_growth_rate = [0.39, 0.09]
# strain=M55212, phase=3, start_time=45.50, start_od=0.84, area=2.09, best_model=EXP (r2=0.56), growth_rate = [0.00, -0.00], specific_growth_rate = [0.00, -0.00]
# strain=M6057, phase=1, start_time=3.00, start_od=0.00, area=4.03, best_model=LGX (r2=1.00), growth_rate = [0.07, 0.03], specific_growth_rate = [0.30, 0.16]
# strain=M6057, phase=2, start_time=26.70, start_od=0.67, area=1.89, best_model=LGX (r2=0.99), growth_rate = [0.62, 0.17], specific_growth_rate = [0.74, 0.20]
# strain=M6057, phase=3, start_time=28.70, start_od=0.99, area=17.70, best_model=EXP (r2=0.28), growth_rate = [0.00, -0.00], specific_growth_rate = [0.00, -0.01]
# strain=M74707, phase=1, start_time=10.80, start_od=0.00, area=0.42, best_model=EXP (r2=1.00), growth_rate = [0.06, 0.01], specific_growth_rate = [0.41, 0.25]
# strain=M74707, phase=2, start_time=22.70, start_od=0.16, area=12.43, best_model=GOM (r2=0.97), growth_rate = [0.04, 0.02], specific_growth_rate = [0.22, 0.05]
# strain=M74707, phase=3, start_time=47.60, start_od=0.66, area=0.27, best_model=LGX (r2=0.93), growth_rate = [0.08, 0.02], specific_growth_rate = [0.11, 0.03]
# strain=PA14, phase=1, start_time=3.90, start_od=0.01, area=0.95, best_model=EXP (r2=1.00), growth_rate = [0.08, 0.02], specific_growth_rate = [0.30, 0.23]
# strain=PA14, phase=2, start_time=20.20, start_od=0.27, area=11.35, best_model=EXP (r2=0.93), growth_rate = [0.05, 0.03], specific_growth_rate = [0.05, 0.05]
# strain=PA14, phase=3, start_time=37.90, start_od=0.88, area=8.70, best_model=EXP (r2=0.98), growth_rate = [0.00, -0.01], specific_growth_rate = [0.00, -0.01]
# strain=PA7, phase=1, start_time=9.40, start_od=0.01, area=4.94, best_model=EXP (r2=0.94), growth_rate = [0.09, 0.03], specific_growth_rate = [0.13, 0.13]
# strain=PA7, phase=2, start_time=35.10, start_od=0.63, area=1.94, best_model=GOM (r2=0.99), growth_rate = [0.10, 0.04], specific_growth_rate = [0.16, 0.06]
# strain=PA7, phase=3, start_time=37.80, start_od=0.75, area=7.62, best_model=GOM (r2=0.90), growth_rate = [0.00, -0.00], specific_growth_rate = [0.00, -0.00]
# strain=PAO1, phase=1, start_time=5.30, start_od=0.01, area=1.62, best_model=EXP (r2=1.00), growth_rate = [0.11, 0.02], specific_growth_rate = [0.27, 0.20]
# strain=PAO1, phase=2, start_time=25.90, start_od=0.43, area=8.84, best_model=GOM (r2=0.96), growth_rate = [0.14, 0.04], specific_growth_rate = [0.28, 0.06]
# strain=PAO1, phase=3, start_time=36.90, start_od=0.96, area=9.82, best_model=LGX (r2=0.71), growth_rate = [0.00, 0.00], specific_growth_rate = [0.00, 0.00]
# strain=S86968, phase=1, start_time=4.40, start_od=0.01, area=6.76, best_model=EXP (r2=0.91), growth_rate = [0.08, 0.03], specific_growth_rate = [0.10, 0.10]
# strain=S86968, phase=2, start_time=31.60, start_od=0.66, area=1.63, best_model=GOM (r2=1.00), growth_rate = [0.12, 0.05], specific_growth_rate = [0.17, 0.08]
# strain=S86968, phase=3, start_time=33.80, start_od=0.78, area=10.15, best_model=EXP (r2=0.99), growth_rate = [0.00, -0.01], specific_growth_rate = [0.00, -0.01]
# strain=T38079, phase=1, start_time=5.10, start_od=0.00, area=1.99, best_model=EXP (r2=1.00), growth_rate = [0.20, 0.03], specific_growth_rate = [0.32, 0.30]
# strain=T38079, phase=2, start_time=23.60, start_od=0.65, area=6.52, best_model=GOM (r2=1.00), growth_rate = [0.23, 0.06], specific_growth_rate = [0.36, 0.08]
# strain=T38079, phase=3, start_time=30.30, start_od=1.07, area=18.59, best_model=EXP (r2=0.40), growth_rate = [0.00, -0.06], specific_growth_rate = [0.00, -0.06]
# strain=T52373, phase=1, start_time=11.70, start_od=0.00, area=1.31, best_model=EXP (r2=1.00), growth_rate = [0.17, 0.03], specific_growth_rate = [0.37, 0.31]
# strain=T52373, phase=2, start_time=25.90, start_od=0.44, area=14.95, best_model=EXP (r2=0.93), growth_rate = [0.05, 0.03], specific_growth_rate = [0.04, 0.04]
# strain=T52373, phase=3, start_time=43.10, start_od=1.10, area=5.35, best_model=EXP (r2=0.23), growth_rate = [0.00, -0.00], specific_growth_rate = [0.00, -0.00]
# strain=T6313, phase=1, start_time=5.70, start_od=0.00, area=2.13, best_model=EXP (r2=0.99), growth_rate = [0.09, 0.02], specific_growth_rate = [0.20, 0.20]
# strain=T6313, phase=2, start_time=24.90, start_od=0.41, area=14.05, best_model=LGX (r2=1.00), growth_rate = [0.04, 0.02], specific_growth_rate = [0.08, 0.04]
# strain=T6313, phase=3, start_time=44.50, start_od=0.89, area=3.07, best_model=EXP (r2=0.90), growth_rate = [0.01, -0.01], specific_growth_rate = [0.01, -0.01]
# strain=T63266, phase=1, start_time=2.80, start_od=0.00, area=1.76, best_model=EXP (r2=1.00), growth_rate = [0.14, 0.02], specific_growth_rate = [0.28, 0.24]
# strain=T63266, phase=2, start_time=22.80, start_od=0.51, area=4.65, best_model=EXP (r2=0.97), growth_rate = [0.12, 0.09], specific_growth_rate = [0.11, 0.11]
# strain=T63266, phase=3, start_time=28.60, start_od=1.00, area=17.55, best_model=EXP (r2=0.32), growth_rate = [0.00, -0.00], specific_growth_rate = [0.00, -0.00]
# strain=W16407, phase=1, start_time=4.00, start_od=0.00, area=1.78, best_model=EXP (r2=0.99), growth_rate = [0.13, 0.03], specific_growth_rate = [0.28, 0.25]
# strain=W16407, phase=2, start_time=22.50, start_od=0.50, area=13.02, best_model=EXP (r2=0.92), growth_rate = [0.03, 0.03], specific_growth_rate = [0.03, 0.03]
# strain=W16407, phase=3, start_time=38.10, start_od=1.01, area=9.75, best_model=EXP (r2=0.99), growth_rate = [0.00, -0.00], specific_growth_rate = [0.00, -0.00]
# strain=W25637, phase=1, start_time=11.00, start_od=0.01, area=1.09, best_model=EXP (r2=0.99), growth_rate = [0.17, 0.02], specific_growth_rate = [0.44, 0.20]
# strain=W25637, phase=2, start_time=26.40, start_od=0.41, area=1.82, best_model=LGX (r2=1.00), growth_rate = [0.21, 0.10], specific_growth_rate = [0.43, 0.19]
# strain=W25637, phase=3, start_time=29.30, start_od=0.72, area=14.82, best_model=GOM (r2=0.98), growth_rate = [0.06, 0.01], specific_growth_rate = [0.08, 0.02]
# strain=W36662, phase=1, start_time=10.50, start_od=0.01, area=4.77, best_model=EXP (r2=0.95), growth_rate = [0.12, 0.03], specific_growth_rate = [0.15, 0.15]
# strain=W36662, phase=2, start_time=32.90, start_od=0.71, area=1.94, best_model=LGX (r2=1.00), growth_rate = [0.18, 0.08], specific_growth_rate = [0.26, 0.10]
# strain=W36662, phase=3, start_time=35.20, start_od=0.89, area=10.28, best_model=EXP (r2=0.96), growth_rate = [0.01, -0.02], specific_growth_rate = [0.01, -0.02]
# strain=W45909, phase=1, start_time=3.00, start_od=0.00, area=1.39, best_model=EXP (r2=1.00), growth_rate = [0.12, 0.02], specific_growth_rate = [0.30, 0.23]
# strain=W45909, phase=2, start_time=22.70, start_od=0.41, area=10.35, best_model=LGX (r2=0.92), growth_rate = [0.04, 0.03], specific_growth_rate = [0.05, 0.05]
# strain=W45909, phase=3, start_time=36.40, start_od=1.03, area=11.55, best_model=EXP (r2=0.13), growth_rate = [0.00, 0.00], specific_growth_rate = [0.00, 0.00]
# strain=W60856, phase=1, start_time=10.10, start_od=0.01, area=4.95, best_model=EXP (r2=0.95), growth_rate = [0.08, 0.03], specific_growth_rate = [0.12, 0.12]
# strain=W60856, phase=2, start_time=32.80, start_od=0.68, area=2.10, best_model=GOM (r2=1.00), growth_rate = [0.33, 0.11], specific_growth_rate = [0.49, 0.14]
# strain=W60856, phase=3, start_time=35.20, start_od=0.94, area=11.61, best_model=EXP (r2=1.00), growth_rate = [0.00, -0.01], specific_growth_rate = [0.00, -0.01]
# strain=W70332, phase=1, start_time=4.10, start_od=0.00, area=10.50, best_model=LGX (r2=1.00), growth_rate = [0.08, 0.03], specific_growth_rate = [0.32, 0.20]
# strain=W70332, phase=2, start_time=33.80, start_od=1.05, area=2.75, best_model=GOM (r2=0.95), growth_rate = [0.24, 0.08], specific_growth_rate = [0.22, 0.07]
# strain=W70332, phase=3, start_time=36.10, start_od=1.23, area=12.86, best_model=EXP (r2=0.93), growth_rate = [0.02, -0.03], specific_growth_rate = [0.02, -0.03]
# strain=W91453, phase=1, start_time=9.10, start_od=0.01, area=0.68, best_model=EXP (r2=0.98), growth_rate = [0.12, 0.02], specific_growth_rate = [0.48, 0.19]
# strain=W91453, phase=2, start_time=23.50, start_od=0.27, area=10.80, best_model=EXP (r2=0.95), growth_rate = [0.04, 0.03], specific_growth_rate = [0.05, 0.05]
# strain=W91453, phase=3, start_time=41.00, start_od=0.89, area=5.94, best_model=EXP (r2=1.00), growth_rate = [0.01, -0.01], specific_growth_rate = [0.01, -0.01]
# strain=X78812, phase=1, start_time=3.50, start_od=0.01, area=1.39, best_model=EXP (r2=1.00), growth_rate = [0.09, 0.02], specific_growth_rate = [0.25, 0.22]
# strain=X78812, phase=2, start_time=23.10, start_od=0.35, area=8.85, best_model=EXP (r2=0.98), growth_rate = [0.05, 0.04], specific_growth_rate = [0.06, 0.06]
# strain=X78812, phase=3, start_time=36.90, start_od=0.89, area=9.89, best_model=GOM (r2=0.46), growth_rate = [0.04, 0.00], specific_growth_rate = [0.05, 0.00]
# strain=X9820, phase=1, start_time=3.00, start_od=0.00, area=0.90, best_model=EXP (r2=1.00), growth_rate = [0.10, 0.02], specific_growth_rate = [0.34, 0.24]
# strain=X9820, phase=2, start_time=18.80, start_od=0.28, area=10.78, best_model=EXP (r2=0.94), growth_rate = [0.04, 0.03], specific_growth_rate = [0.05, 0.05]
# strain=X9820, phase=3, start_time=36.50, start_od=0.87, area=8.65, best_model=EXP (r2=0.44), growth_rate = [0.00, -0.02], specific_growth_rate = [0.00, -0.02]

# %%
df_growth_curve_feature = df_growth_curve_feature.fillna(0.0)
df_growth_curve_feature.head()
# Out:
#    strain phase  start_time  end_time  delta_time  start_od  delta_od  \
# 0  F22031     1         3.3      20.6        17.3  0.006426  0.341041
# 1  F22031     2        20.6      36.7        16.1  0.347467  0.669791
# 2  F22031     3        36.7      48.0        11.3  1.017258 -0.046485
# 3  F23197     1        12.8      32.5        19.7  0.008182  0.416802
# 4  F23197     2        32.5      43.6        11.1  0.424984  0.469181
#
#         area best_model        r2  growth_rate_max  growth_rate_mean  \
# 0   1.449650        EXP  0.996811         0.092024          0.021197
# 1  11.985124        EXP  0.945412         0.065825          0.042927
# 2  11.244500        EXP  0.989257         0.003777         -0.004222
# 3   2.441355        EXP  0.975862         0.091943          0.024289
# 4   7.573974        EXP  0.982909         0.053892          0.039710
#
#    specific_growth_rate_max  specific_growth_rate_mean
# 0                  0.249327                   0.249327
# 1                  0.057574                   0.057574
# 2                  0.003710                  -0.004248
# 3                  0.188350                   0.188350
# 4                  0.058201                   0.058201

# %%
df_growth_curve_feature.to_csv('tblgcfeatures.csv')

# %% [markdown]
# ## run feature selection using random forest

# %%
df_classification = pd.read_csv('tblgcfeatures.csv', index_col=0)
df_classification.drop(['r2','end_time','best_model','growth_rate_max','growth_rate_mean'], axis=1)
df_classification.phase = df_classification.phase.astype(str)
df_classification = pd.pivot_table(df_classification, 
                         values=['start_time','delta_time','start_od','delta_od','area','specific_growth_rate_max','specific_growth_rate_mean'],
                         index=['strain'],
                         columns=['phase'],
                         aggfunc=np.mean
                        )
df_classification.columns = ['__'.join(x) for x in df_classification.columns.to_flat_index()]
df_classification = pd.merge(df_classification, df_rhl.set_index('strain',drop=True), left_on='strain', right_on='strain', how='left')
df_classification.drop(['rhamn3cats'], axis=1, inplace=True)
df_classification = df_classification[df_classification['rhamn2cats'].notnull()] # remove strains which do not have data for rhamnolipid production
df_classification['rhamn2cats'] = df_classification['rhamn2cats'].astype('category')

# # in case: remove rows and column whose values are all NaN
# df_classification = df_classification.dropna(axis=0,how='all')
# df_classification = df_classification.dropna(axis=1,how='all')

df_classification.head()
# Out:
#          area__1    area__2    area__3  delta_od__1  delta_od__2  delta_od__3  \
# strain
# F22031  1.449650  11.985124  11.244500     0.341041     0.669791    -0.046485
# F23197  2.441355   7.573974   3.763219     0.416802     0.469181    -0.100917
# F30658  1.026965   4.154665  12.665739     0.382177     0.413794    -0.330257
# F34365  1.510287  10.572320  10.553631     0.370286     0.571256    -0.059464
# F5677   7.111104   0.065506   0.000000     0.641946     0.004151     0.000000
#
#         delta_time__1  delta_time__2  delta_time__3  \
# strain
# F22031           17.3           16.1           11.3
# F23197           19.7           11.1            4.4
# F30658           17.8            6.2           19.6
# F34365           17.1           14.8           11.7
# F5677            32.5            0.1            0.0
#
#         specific_growth_rate_max__1  ...  specific_growth_rate_mean__1  \
# strain                               ...
# F22031                     0.249327  ...                      0.249327
# F23197                     0.188350  ...                      0.188350
# F30658                     0.523181  ...                      0.157303
# F34365                     0.264798  ...                      0.233196
# F5677                      0.091215  ...                      0.091215
#
#         specific_growth_rate_mean__2  specific_growth_rate_mean__3  \
# strain
# F22031                      0.057574                     -0.004248
# F23197                      0.058201                     -0.024434
# F30658                      0.109881                     -0.027186
# F34365                      0.050129                     -0.007589
# F5677                       0.063366                      0.005319
#
#         start_od__1  start_od__2  start_od__3  start_time__1  start_time__2  \
# strain
# F22031     0.006426     0.347467     1.017258            3.3           20.6
# F23197     0.008182     0.424984     0.894164           12.8           32.5
# F30658     0.006743     0.388921     0.802715            4.4           22.2
# F34365     0.008560     0.378846     0.950102            4.4           21.5
# F5677      0.011036     0.652982     0.657133           15.4           47.9
#
#         start_time__3  rhamn2cats
# strain
# F22031           36.7         1.0
# F23197           43.6         1.0
# F30658           28.4         1.0
# F34365           36.3         1.0
# F5677            48.0         0.0
#
# [5 rows x 22 columns]

# %%
X = df_classification.iloc[:,0:len(df_classification.columns)-1]
y = df_classification.iloc[:,-1]
model_rf = RandomForestClassifier(n_estimators=100000, n_jobs=-1, random_state=0)
model_rf.fit(X,y)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100000,
#                        n_jobs=-1, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
fig, ax = plt.subplots(1,1,figsize=(8,6))
feat_importances = pd.Series(model_rf.feature_importances_, index=X.columns)
feat_importances.nlargest(1000).plot(kind='bar')
plt.show()
fig.savefig('feature_importance_RF.svg', format='svg', dpi=1200)

# %% [markdown]
# ## Test significance of features

# %%
pvallist = []
featurelist = []
for feature in df_classification.columns:
    if feature != 'rhamn2cats':
        RL_non_producing_group = list(df_classification.loc[df_classification.rhamn2cats==0, feature].values)
        RL_producing_group = list(df_classification.loc[df_classification.rhamn2cats==1, feature].values)
        _,pval = scipy.stats.ttest_ind(RL_non_producing_group, RL_producing_group, equal_var=False)
        pvallist.append(pval)
        featurelist.append(feature)
        
order = np.argsort(pvallist)
pvallist = [pvallist[x] for x in order]
featurelist = [featurelist[x] for x in order]

for feature,pval in zip(featurelist, pvallist):
    if (pval <= 0.05):
        print("SIGNIFICANT, %s, p-value = %2.2e"%(feature, pval))
    else:
        print("NOT SIGNIFICANT, %s, p-value = %2.2e"%(feature, pval))
# Out:
# SIGNIFICANT, specific_growth_rate_max__1, p-value = 5.11e-04
# NOT SIGNIFICANT, delta_time__1, p-value = 5.40e-02
# NOT SIGNIFICANT, specific_growth_rate_mean__1, p-value = 5.55e-02
# NOT SIGNIFICANT, area__1, p-value = 6.50e-02
# NOT SIGNIFICANT, start_od__1, p-value = 1.06e-01
# NOT SIGNIFICANT, delta_od__2, p-value = 1.12e-01
# NOT SIGNIFICANT, start_time__2, p-value = 1.15e-01
# NOT SIGNIFICANT, area__2, p-value = 1.40e-01
# NOT SIGNIFICANT, delta_time__2, p-value = 1.73e-01
# NOT SIGNIFICANT, specific_growth_rate_max__3, p-value = 1.92e-01
# NOT SIGNIFICANT, start_od__2, p-value = 2.11e-01
# NOT SIGNIFICANT, delta_od__1, p-value = 2.18e-01
# NOT SIGNIFICANT, start_od__3, p-value = 2.89e-01
# NOT SIGNIFICANT, area__3, p-value = 3.60e-01
# NOT SIGNIFICANT, start_time__3, p-value = 3.82e-01
# NOT SIGNIFICANT, delta_time__3, p-value = 3.82e-01
# NOT SIGNIFICANT, start_time__1, p-value = 4.37e-01
# NOT SIGNIFICANT, delta_od__3, p-value = 6.73e-01
# NOT SIGNIFICANT, specific_growth_rate_mean__2, p-value = 7.02e-01
# NOT SIGNIFICANT, specific_growth_rate_mean__3, p-value = 7.88e-01
# NOT SIGNIFICANT, specific_growth_rate_max__2, p-value = 8.65e-01

# %% [markdown]
# ## Plot comparison of features between producing and non-producing strains

# %%
features_to_compare = ['specific_growth_rate_max__1',
                       'specific_growth_rate_mean__1',
                       'delta_time__1',
                       'start_od__1']

fig, ax = plt.subplots(1,len(features_to_compare),figsize=(6, 2.5*len(features_to_compare)))
for index, feature in enumerate(features_to_compare):
    g = sns.boxplot(x='rhamn2cats', y=feature, data=df_classification, ax=ax[index])
    g.set_xticklabels(g.get_xticklabels(), rotation=90)
    
plt.tight_layout()
plt.show()
