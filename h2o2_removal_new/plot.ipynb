# %%
import matplotlib.pyplot as plt

# %%
plt.bar([1,2,3],[0,1.20,1.41],color='None')
plt.errorbar([1,2,3],[0,1.20,1.41], yerr=[[0,0.48,0.84],[0,1.92,1.98]])

plt.tight_layout()
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig('effect_size_h2o2_removal.svg', dpi=600)
