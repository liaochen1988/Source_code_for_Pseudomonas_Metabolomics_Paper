# %%
import BBH_python3
import pandas as pd
import os

# %% [markdown]
# # We only include strains that have rhamnnolipid production data

# %%
df_rhl = pd.read_excel('../data/rhamnolipids/rhamnMat.xlsx', index_col=0)
df_rhl.head()
# Out:
#         rhamn3cats  rhamn2cats
# strain
# F22031           2           1
# F23197           2           1
# F30658           1           1
# F34365           2           1
# F5677            0           0

# %% [markdown]
# # Do reciprocal blast

# %%
subject = 'PA_UCBPP-PA14_feature_protein'

for strain in df_rhl.index:
    if strain == 'PA14':
        continue
    outfile = 'PA14_vs_'+strain+'.txt'
    if not os.path.isfile(outfile):
        query = 'PA_' + strain + '_feature_protein'
        BBH_python3.make_blast_db(subject)
        BBH_python3.make_blast_db(query)
        BBH_python3.get_bbh(query, subject, in_folder='bbh', outfile=outfile)
# Out:
# making blast db with following command line...
# makeblastdb -in prots/PA_UCBPP-PA14_feature_protein.faa -dbtype prot
# making blast db with following command line...
# makeblastdb -in prots/PA_F22031_feature_protein.faa -dbtype prot
# blasting PA_F22031_feature_protein vs PA_UCBPP-PA14_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_UCBPP-PA14_feature_protein.faa -query prots/PA_F22031_feature_protein.faa -out bbh/PA_F22031_feature_protein_vs_PA_UCBPP-PA14_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# blasting PA_UCBPP-PA14_feature_protein vs PA_F22031_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_F22031_feature_protein.faa -query prots/PA_UCBPP-PA14_feature_protein.faa -out bbh/PA_UCBPP-PA14_feature_protein_vs_PA_F22031_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# parsing BBHs for PA_F22031_feature_protein PA_UCBPP-PA14_feature_protein
# /Users/liaoc/Documents/Source_code_for_Pseudomonas_Metabolomics_Paper/find_protein_orthologues/BBH_python3.py:297: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '<=>'
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/liaoc/Documents/Source_code_for_Pseudomonas_Metabolomics_Paper/find_protein_orthologues/BBH_python3.py:300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_hit['BBH'] = '->'
# making blast db with following command line...
# makeblastdb -in prots/PA_UCBPP-PA14_feature_protein.faa -dbtype prot
# making blast db with following command line...
# makeblastdb -in prots/PA_F23197_feature_protein.faa -dbtype prot
# blasting PA_F23197_feature_protein vs PA_UCBPP-PA14_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_UCBPP-PA14_feature_protein.faa -query prots/PA_F23197_feature_protein.faa -out bbh/PA_F23197_feature_protein_vs_PA_UCBPP-PA14_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# blasting PA_UCBPP-PA14_feature_protein vs PA_F23197_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_F23197_feature_protein.faa -query prots/PA_UCBPP-PA14_feature_protein.faa -out bbh/PA_UCBPP-PA14_feature_protein_vs_PA_F23197_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# parsing BBHs for PA_F23197_feature_protein PA_UCBPP-PA14_feature_protein
# making blast db with following command line...
# makeblastdb -in prots/PA_UCBPP-PA14_feature_protein.faa -dbtype prot
# making blast db with following command line...
# makeblastdb -in prots/PA_F30658_feature_protein.faa -dbtype prot
# blasting PA_F30658_feature_protein vs PA_UCBPP-PA14_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_UCBPP-PA14_feature_protein.faa -query prots/PA_F30658_feature_protein.faa -out bbh/PA_F30658_feature_protein_vs_PA_UCBPP-PA14_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# blasting PA_UCBPP-PA14_feature_protein vs PA_F30658_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_F30658_feature_protein.faa -query prots/PA_UCBPP-PA14_feature_protein.faa -out bbh/PA_UCBPP-PA14_feature_protein_vs_PA_F30658_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# parsing BBHs for PA_F30658_feature_protein PA_UCBPP-PA14_feature_protein
# making blast db with following command line...
# makeblastdb -in prots/PA_UCBPP-PA14_feature_protein.faa -dbtype prot
# making blast db with following command line...
# makeblastdb -in prots/PA_F34365_feature_protein.faa -dbtype prot
# blasting PA_F34365_feature_protein vs PA_UCBPP-PA14_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_UCBPP-PA14_feature_protein.faa -query prots/PA_F34365_feature_protein.faa -out bbh/PA_F34365_feature_protein_vs_PA_UCBPP-PA14_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# blasting PA_UCBPP-PA14_feature_protein vs PA_F34365_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_F34365_feature_protein.faa -query prots/PA_UCBPP-PA14_feature_protein.faa -out bbh/PA_UCBPP-PA14_feature_protein_vs_PA_F34365_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# parsing BBHs for PA_F34365_feature_protein PA_UCBPP-PA14_feature_protein
# making blast db with following command line...
# makeblastdb -in prots/PA_UCBPP-PA14_feature_protein.faa -dbtype prot
# making blast db with following command line...
# makeblastdb -in prots/PA_F5677_feature_protein.faa -dbtype prot
# blasting PA_F5677_feature_protein vs PA_UCBPP-PA14_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_UCBPP-PA14_feature_protein.faa -query prots/PA_F5677_feature_protein.faa -out bbh/PA_F5677_feature_protein_vs_PA_UCBPP-PA14_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# blasting PA_UCBPP-PA14_feature_protein vs PA_F5677_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_F5677_feature_protein.faa -query prots/PA_UCBPP-PA14_feature_protein.faa -out bbh/PA_UCBPP-PA14_feature_protein_vs_PA_F5677_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# parsing BBHs for PA_F5677_feature_protein PA_UCBPP-PA14_feature_protein
# making blast db with following command line...
# makeblastdb -in prots/PA_UCBPP-PA14_feature_protein.faa -dbtype prot
# making blast db with following command line...
# makeblastdb -in prots/PA_F63912_feature_protein.faa -dbtype prot
# blasting PA_F63912_feature_protein vs PA_UCBPP-PA14_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_UCBPP-PA14_feature_protein.faa -query prots/PA_F63912_feature_protein.faa -out bbh/PA_F63912_feature_protein_vs_PA_UCBPP-PA14_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# blasting PA_UCBPP-PA14_feature_protein vs PA_F63912_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_F63912_feature_protein.faa -query prots/PA_UCBPP-PA14_feature_protein.faa -out bbh/PA_UCBPP-PA14_feature_protein_vs_PA_F63912_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# parsing BBHs for PA_F63912_feature_protein PA_UCBPP-PA14_feature_protein
# making blast db with following command line...
# makeblastdb -in prots/PA_UCBPP-PA14_feature_protein.faa -dbtype prot
# making blast db with following command line...
# makeblastdb -in prots/PA_F9670_feature_protein.faa -dbtype prot
# blasting PA_F9670_feature_protein vs PA_UCBPP-PA14_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_UCBPP-PA14_feature_protein.faa -query prots/PA_F9670_feature_protein.faa -out bbh/PA_F9670_feature_protein_vs_PA_UCBPP-PA14_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# blasting PA_UCBPP-PA14_feature_protein vs PA_F9670_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_F9670_feature_protein.faa -query prots/PA_UCBPP-PA14_feature_protein.faa -out bbh/PA_UCBPP-PA14_feature_protein_vs_PA_F9670_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# parsing BBHs for PA_F9670_feature_protein PA_UCBPP-PA14_feature_protein
# making blast db with following command line...
# makeblastdb -in prots/PA_UCBPP-PA14_feature_protein.faa -dbtype prot
# making blast db with following command line...
# makeblastdb -in prots/PA_H27930_feature_protein.faa -dbtype prot
# blasting PA_H27930_feature_protein vs PA_UCBPP-PA14_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_UCBPP-PA14_feature_protein.faa -query prots/PA_H27930_feature_protein.faa -out bbh/PA_H27930_feature_protein_vs_PA_UCBPP-PA14_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# blasting PA_UCBPP-PA14_feature_protein vs PA_H27930_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_H27930_feature_protein.faa -query prots/PA_UCBPP-PA14_feature_protein.faa -out bbh/PA_UCBPP-PA14_feature_protein_vs_PA_H27930_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# parsing BBHs for PA_H27930_feature_protein PA_UCBPP-PA14_feature_protein
# making blast db with following command line...
# makeblastdb -in prots/PA_UCBPP-PA14_feature_protein.faa -dbtype prot
# making blast db with following command line...
# makeblastdb -in prots/PA_H47921_feature_protein.faa -dbtype prot
# blasting PA_H47921_feature_protein vs PA_UCBPP-PA14_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_UCBPP-PA14_feature_protein.faa -query prots/PA_H47921_feature_protein.faa -out bbh/PA_H47921_feature_protein_vs_PA_UCBPP-PA14_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# blasting PA_UCBPP-PA14_feature_protein vs PA_H47921_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_H47921_feature_protein.faa -query prots/PA_UCBPP-PA14_feature_protein.faa -out bbh/PA_UCBPP-PA14_feature_protein_vs_PA_H47921_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# parsing BBHs for PA_H47921_feature_protein PA_UCBPP-PA14_feature_protein
# making blast db with following command line...
# makeblastdb -in prots/PA_UCBPP-PA14_feature_protein.faa -dbtype prot
# making blast db with following command line...
# makeblastdb -in prots/PA_H5708_feature_protein.faa -dbtype prot
# blasting PA_H5708_feature_protein vs PA_UCBPP-PA14_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_UCBPP-PA14_feature_protein.faa -query prots/PA_H5708_feature_protein.faa -out bbh/PA_H5708_feature_protein_vs_PA_UCBPP-PA14_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# blasting PA_UCBPP-PA14_feature_protein vs PA_H5708_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_H5708_feature_protein.faa -query prots/PA_UCBPP-PA14_feature_protein.faa -out bbh/PA_UCBPP-PA14_feature_protein_vs_PA_H5708_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# parsing BBHs for PA_H5708_feature_protein PA_UCBPP-PA14_feature_protein
# making blast db with following command line...
# makeblastdb -in prots/PA_UCBPP-PA14_feature_protein.faa -dbtype prot
# making blast db with following command line...
# makeblastdb -in prots/PA_M1608_feature_protein.faa -dbtype prot
# blasting PA_M1608_feature_protein vs PA_UCBPP-PA14_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_UCBPP-PA14_feature_protein.faa -query prots/PA_M1608_feature_protein.faa -out bbh/PA_M1608_feature_protein_vs_PA_UCBPP-PA14_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# blasting PA_UCBPP-PA14_feature_protein vs PA_M1608_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_M1608_feature_protein.faa -query prots/PA_UCBPP-PA14_feature_protein.faa -out bbh/PA_UCBPP-PA14_feature_protein_vs_PA_M1608_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# parsing BBHs for PA_M1608_feature_protein PA_UCBPP-PA14_feature_protein
# making blast db with following command line...
# makeblastdb -in prots/PA_UCBPP-PA14_feature_protein.faa -dbtype prot
# making blast db with following command line...
# makeblastdb -in prots/PA
feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# parsing BBHs for PA_X78812_feature_protein PA_UCBPP-PA14_feature_protein
# making blast db with following command line...
# makeblastdb -in prots/PA_UCBPP-PA14_feature_protein.faa -dbtype prot
# making blast db with following command line...
# makeblastdb -in prots/PA_X9820_feature_protein.faa -dbtype prot
# blasting PA_X9820_feature_protein vs PA_UCBPP-PA14_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_UCBPP-PA14_feature_protein.faa -query prots/PA_X9820_feature_protein.faa -out bbh/PA_X9820_feature_protein_vs_PA_UCBPP-PA14_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# blasting PA_UCBPP-PA14_feature_protein vs PA_X9820_feature_protein
# running blastp with following command line...
# blastp -db prots/PA_X9820_feature_protein.faa -query prots/PA_UCBPP-PA14_feature_protein.faa -out bbh/PA_UCBPP-PA14_feature_protein_vs_PA_X9820_feature_protein.txt -evalue 0.001 -outfmt 6 -num_threads 12
# parsing BBHs for PA_X9820_feature_protein PA_UCBPP-PA14_feature_protein

# %% [markdown]
# # Find core proteome

# %%
df_orth = pd.DataFrame()
for index,strain in enumerate(df_rhl.index):
    if strain=='PA14':
        continue
    infile = 'PA14_vs_'+strain+'.txt'
    df = pd.read_csv(infile, sep=',', index_col=0).reset_index()
    df = df[df.BBH == '<=>'] # select only orthologue
    df = df[['gene','subject']]
    df.columns = [strain, 'PA14']
    df = df.set_index('PA14')
    if index==0:
        df_orth = df
    else:
        df_orth = pd.merge(df_orth, df, left_index=True, right_index=True, how='inner')
        
df_orth.index = [x.rstrip('|') for x in df_orth.index]
df_orth.head()
# Out:
#                                 F22031              F23197  \
# fig|287.6770.peg.1  fig|287.6613.peg.1  fig|287.6611.peg.1
# fig|287.6770.peg.2  fig|287.6613.peg.2  fig|287.6611.peg.2
# fig|287.6770.peg.3  fig|287.6613.peg.3  fig|287.6611.peg.3
# fig|287.6770.peg.4  fig|287.6613.peg.4  fig|287.6611.peg.4
# fig|287.6770.peg.6  fig|287.6613.peg.5  fig|287.6611.peg.5
#
#                                 F30658              F34365  \
# fig|287.6770.peg.1  fig|287.6614.peg.1  fig|287.6616.peg.1
# fig|287.6770.peg.2  fig|287.6614.peg.2  fig|287.6616.peg.2
# fig|287.6770.peg.3  fig|287.6614.peg.3  fig|287.6616.peg.3
# fig|287.6770.peg.4  fig|287.6614.peg.4  fig|287.6616.peg.4
# fig|287.6770.peg.6  fig|287.6614.peg.5  fig|287.6616.peg.5
#
#                                  F5677              F63912  \
# fig|287.6770.peg.1  fig|287.6612.peg.1  fig|287.6618.peg.1
# fig|287.6770.peg.2  fig|287.6612.peg.2  fig|287.6618.peg.2
# fig|287.6770.peg.3  fig|287.6612.peg.3  fig|287.6618.peg.3
# fig|287.6770.peg.4  fig|287.6612.peg.4  fig|287.6618.peg.4
# fig|287.6770.peg.6  fig|287.6612.peg.6  fig|287.6618.peg.5
#
#                                   F9670              H27930  \
# fig|287.6770.peg.1   fig|287.6615.peg.1  fig|287.6617.peg.1
# fig|287.6770.peg.2   fig|287.6615.peg.2  fig|287.6617.peg.2
# fig|287.6770.peg.3   fig|287.6615.peg.3  fig|287.6617.peg.3
# fig|287.6770.peg.4   fig|287.6615.peg.4  fig|287.6617.peg.4
# fig|287.6770.peg.6  fig|287.6615.peg.12  fig|287.6617.peg.5
#
#                                 H47921               H5708  ...  \
# fig|287.6770.peg.1  fig|287.6621.peg.1  fig|287.6619.peg.1  ...
# fig|287.6770.peg.2  fig|287.6621.peg.2  fig|287.6619.peg.2  ...
# fig|287.6770.peg.3  fig|287.6621.peg.3  fig|287.6619.peg.3  ...
# fig|287.6770.peg.4  fig|287.6621.peg.4  fig|287.6619.peg.4  ...
# fig|287.6770.peg.6  fig|287.6621.peg.5  fig|287.6619.peg.5  ...
#
#                                 T63266              W16407  \
# fig|287.6770.peg.1  fig|287.6635.peg.1  fig|287.6633.peg.1
# fig|287.6770.peg.2  fig|287.6635.peg.2  fig|287.6633.peg.2
# fig|287.6770.peg.3  fig|287.6635.peg.3  fig|287.6633.peg.3
# fig|287.6770.peg.4  fig|287.6635.peg.4  fig|287.6633.peg.4
# fig|287.6770.peg.6  fig|287.6635.peg.5  fig|287.6633.peg.5
#
#                                 W25637              W36662  \
# fig|287.6770.peg.1  fig|287.6634.peg.1  fig|287.6637.peg.1
# fig|287.6770.peg.2  fig|287.6634.peg.2  fig|287.6637.peg.2
# fig|287.6770.peg.3  fig|287.6634.peg.3  fig|287.6637.peg.3
# fig|287.6770.peg.4  fig|287.6634.peg.4  fig|287.6637.peg.4
# fig|287.6770.peg.6  fig|287.6634.peg.5  fig|287.6637.peg.5
#
#                                 W45909              W60856  \
# fig|287.6770.peg.1  fig|287.6636.peg.1  fig|287.6620.peg.1
# fig|287.6770.peg.2  fig|287.6636.peg.2  fig|287.6620.peg.2
# fig|287.6770.peg.3  fig|287.6636.peg.3  fig|287.6620.peg.3
# fig|287.6770.peg.4  fig|287.6636.peg.4  fig|287.6620.peg.4
# fig|287.6770.peg.6  fig|287.6636.peg.5  fig|287.6620.peg.5
#
#                                 W70332              W91453  \
# fig|287.6770.peg.1  fig|287.6630.peg.1  fig|287.6639.peg.1
# fig|287.6770.peg.2  fig|287.6630.peg.2  fig|287.6639.peg.2
# fig|287.6770.peg.3  fig|287.6630.peg.3  fig|287.6639.peg.3
# fig|287.6770.peg.4  fig|287.6630.peg.4  fig|287.6639.peg.4
# fig|287.6770.peg.6  fig|287.6630.peg.5  fig|287.6639.peg.5
#
#                                  X78812               X9820
# fig|287.6770.peg.1   fig|287.6638.peg.1  fig|287.6627.peg.1
# fig|287.6770.peg.2   fig|287.6638.peg.2  fig|287.6627.peg.2
# fig|287.6770.peg.3   fig|287.6638.peg.3  fig|287.6627.peg.3
# fig|287.6770.peg.4   fig|287.6638.peg.4  fig|287.6627.peg.4
# fig|287.6770.peg.6  fig|287.6638.peg.11  fig|287.6627.peg.5
#
# [5 rows x 30 columns]

# %%
len(df_orth.index)
# Out:
# 4003

# %%
# check if thee is NaN
df_orth.isna().any().any()
# Out:
# False

# %%
df_orth.to_csv('protein_orthologue_dictionary_ref_PA14.csv')
